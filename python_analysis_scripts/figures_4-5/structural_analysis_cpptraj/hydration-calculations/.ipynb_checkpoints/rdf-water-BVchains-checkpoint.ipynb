# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
r1 = np.loadtxt('prn1A-rdf.dat', usecols=0, skiprows=0)
g1 = np.loadtxt('prn1A-rdf.dat', usecols=1, skiprows=0)
I1 = np.loadtxt('int-1a.dat', usecols=1, skiprows=0)
I1[10]

r2 = np.loadtxt('prn2A-rdf.dat', usecols=0, skiprows=0)
g2 = np.loadtxt('prn2A-rdf.dat', usecols=1, skiprows=0)
I2 = np.loadtxt('int-2a.dat', usecols=1, skiprows=0)

r3 = np.loadtxt('prn1D-rdf.dat', usecols=0, skiprows=0)
g3 = np.loadtxt('prn1D-rdf.dat', usecols=1, skiprows=0)
I3 = np.loadtxt('int-1d.dat', usecols=1, skiprows=0)

r4 = np.loadtxt('prn2D-rdf.dat', usecols=0, skiprows=0)
g4 = np.loadtxt('prn2D-rdf.dat', usecols=1, skiprows=0)
I4 = np.loadtxt('int-2d.dat', usecols=1, skiprows=0)

# %%
print(r1[35],I1[35])
print(r2[35],I2[35])
print(r3[35],I3[35])
print(r4[35],I4[35])
# Out:
# 3.55 3.138353
# 3.55 3.247059
# 3.55 3.213176
# 3.55 3.156863

# %%
plt.plot(r1, g1, color='green', label='1A')
plt.plot(r2, g2, color='Lightgreen', label='2A')
plt.plot(r3, g3, color='red', label='1D')
plt.plot(r4, g4, color='salmon', label='2D')
plt.legend(loc='best')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
