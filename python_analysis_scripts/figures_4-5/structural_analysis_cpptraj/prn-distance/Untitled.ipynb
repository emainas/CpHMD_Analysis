# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = np.loadtxt('1-intra-BV.out',skiprows=0)
x1=data1[:,0]
r1=data1[:,1]
data2 = np.loadtxt('2-intra-BV.out',skiprows=0)
x2=data2[:,0]
r2=data2[:,1]
data3 = np.loadtxt('3-intra-BV.out',skiprows=0)
x3=data3[:,0]
r3=data3[:,1]
data4 = np.loadtxt('4-intra-BV.out',skiprows=0)
x=data4[:,0]
r1=data4[:,1]

# %%
rho, bins = np.histogram(r1,bins=100)
plt.plot(x1,r1)
plt.show()
